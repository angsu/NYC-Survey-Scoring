# %%
import pandas as pd
import numpy as np

from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# %%
nine = pd.read_excel('scores091011.xlsx', sheet_name='Sheet1')
twelve = pd.read_excel('scores12_18.xlsx', sheet_name='Sheet1')

nine=nine.iloc[1:]
nine.set_index('Unnamed: 0',inplace=True)
names9 = nine.columns.values
names9 = pd.Series(names9)
nine.columns = names9.str.split('.').str[0]



twelve = twelve.iloc[1:]
twelve.set_index('Unnamed: 0',inplace=True)
df = twelve['school_name']
twelve = twelve.drop('school_name',axis=1)
names12 = twelve.columns.values
names12 = pd.Series(names12)
twelve.columns = names12.str.split('.').str[0]

# %%
pd.concat([nine,twelve],axis=1,sort=False)
# Out:
#                         school_name           sch_type         blue0  \
# question                        NaN                NaN  Myschoolhelp
# year                            NaN                NaN          2009
# color                           NaN                NaN          blue
# 01M015    P.S. 015 Roberto Clemente  Elementary School           NaN
# 01M019          P.S. 019 Asher Levy  Elementary School           NaN
# ...                             ...                ...           ...
# 75X469                          NaN                NaN           NaN
# 84K876                          NaN                NaN           NaN
# 84K892                          NaN                NaN           NaN
# 84Q373                          NaN                NaN           NaN
# 84X585                          NaN                NaN           NaN
#
#                  blue1         blue2         blue3         blue4  \
# question  Someoneatmys  Myteachersex  Approximatel  Approximatel
# year              2009          2009          2009          2009
# color             blue          blue          blue          blue
# 01M015             NaN           NaN           NaN           NaN
# 01M019             NaN           NaN           NaN           NaN
# ...                ...           ...           ...           ...
# 75X469             NaN           NaN           NaN           NaN
# 84K876             NaN           NaN           NaN           NaN
# 84K892             NaN           NaN           NaN           NaN
# 84Q373             NaN           NaN           NaN           NaN
# 84X585             NaN           NaN           NaN           NaN
#
#                orange0       orange1       orange2  ...      yellow42  \
# question  Ifeelwelcome  Mostofthetea  Theadultsatm  ...  Myteachersno
# year              2009          2009          2009  ...          2018
# color           orange        orange        orange  ...        yellow
# 01M015             NaN           NaN           NaN  ...           NaN
# 01M019             NaN           NaN           NaN  ...           NaN
# ...                ...           ...           ...  ...           ...
# 75X469             NaN           NaN           NaN  ...             2
# 84K876             NaN           NaN           NaN  ...           NaN
# 84K892             NaN           NaN           NaN  ...      0.534653
# 84Q373             NaN           NaN           NaN  ...          0.19
# 84X585             NaN           NaN           NaN  ...          0.86
#
#               yellow43      yellow44      yellow54      yellow46  \
# question  Myteachersgi  Myteachersex  Myteacherssu  I’mlearninga
# year              2018          2018          2018          2018
# color           yellow        yellow        yellow        yellow
# 01M015             NaN           NaN           NaN           NaN
# 01M019             NaN           NaN           NaN           NaN
# ...                ...           ...           ...           ...
# 75X469               2             2             2           NaN
# 84K876             NaN           NaN           NaN           NaN
# 84K892            0.55          0.61           0.2          1.05
# 84Q373        0.292929      0.405941           0.1          0.41
# 84X585            1.09          1.05      0.646465          1.29
#
#               yellow34      yellow35      yellow36      yellow47      yellow53
# question  Thereisatlea  Myteacherstr  Whenmyteache  Disciplineis  Adultsatthis
# year              2018          2018          2018          2018          2018
# color           yellow        yellow        yellow        yellow        yellow
# 01M015             NaN           NaN           NaN           NaN           NaN
# 01M019             NaN           NaN           NaN           NaN           NaN
# ...                ...           ...           ...           ...           ...
# 75X469             NaN           NaN           NaN           NaN           NaN
# 84K876             NaN           NaN           NaN           NaN           NaN
# 84K892            1.38          1.09      0.722772      0.535354          1.34
# 84Q373            1.08           0.9          0.52     0.0606061      0.525253
# 84X585            1.35           1.4       1.11111          0.56           NaN
#
# [2219 rows x 440 columns]

# %%
df
# Out:
# Unnamed: 0
# question                                                  NaN
# year                                                      NaN
# color                                                     NaN
# 01M015                              P.S. 015 Roberto Clemente
# 01M019                                    P.S. 019 Asher Levy
#                                   ...
# 75X469       P469X - THE BRONX SCHOOL FOR CONTINUOUS LEARNERS
# 84K876               ACHIEVEMENT FIRST VOYAGER CHARTER SCHOOL
# 84K892                      BROOKLYN EMERGING LEADERS ACADEMY
# 84Q373      NEW VISIONS CHARTER HIGH SCHOOL FOR THE HUMANI...
# 84X585                             LEGACY COLLEGE PREPARATORY
# Name: school_name, Length: 2150, dtype: object

# %%
#get mean
result = pd.DataFrame()
result = pd.concat([nine,twelve],axis=1,sort=False)
for j in range(3,len(result)):
    if pd.isnull(result.iloc[j,0]):
        idx = result.index[j]
        result.iloc[j,0] = df.loc[idx]
result['sch_mean_allyrs'] = 'NaN'
result = pd.concat([result[['sch_mean_allyrs']], result.drop('sch_mean_allyrs', axis=1)], axis=1)
result = result.reset_index()

for i in range(3,len(result)):
    formean = result.iloc[i,4:]
    result.loc[i,'sch_mean_allyrs'] = formean.mean(skipna = True)

# %%
result
# Out:
#          index sch_mean_allyrs  \
# 0     question             NaN
# 1         year             NaN
# 2        color             NaN
# 3       01M015             NaN
# 4       01M019             NaN
# ...        ...             ...
# 2214    75X469               2
# 2215    84K876             NaN
# 2216    84K892        0.743198
# 2217    84Q373        0.429343
# 2218    84X585        0.896481
#
#                                             school_name           sch_type  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                             P.S. 015 Roberto Clemente  Elementary School
# 4                                   P.S. 019 Asher Levy  Elementary School
# ...                                                 ...                ...
# 2214   P469X - THE BRONX SCHOOL FOR CONTINUOUS LEARNERS                NaN
# 2215           ACHIEVEMENT FIRST VOYAGER CHARTER SCHOOL                NaN
# 2216                  BROOKLYN EMERGING LEADERS ACADEMY                NaN
# 2217  NEW VISIONS CHARTER HIGH SCHOOL FOR THE HUMANI...                NaN
# 2218                         LEGACY COLLEGE PREPARATORY                NaN
#
#              blue0         blue1         blue2         blue3         blue4  \
# 0     Myschoolhelp  Someoneatmys  Myteachersex  Approximatel  Approximatel
# 1             2009          2009          2009          2009          2009
# 2             blue          blue          blue          blue          blue
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 2214           NaN           NaN           NaN           NaN           NaN
# 2215           NaN           NaN           NaN           NaN           NaN
# 2216           NaN           NaN           NaN           NaN           NaN
# 2217           NaN           NaN           NaN           NaN           NaN
# 2218           NaN           NaN           NaN           NaN           NaN
#
#            orange0  ...      yellow42      yellow43      yellow44  \
# 0     Ifeelwelcome  ...  Myteachersno  Myteachersgi  Myteachersex
# 1             2009  ...          2018          2018          2018
# 2           orange  ...        yellow        yellow        yellow
# 3              NaN  ...           NaN           NaN           NaN
# 4              NaN  ...           NaN           NaN           NaN
# ...            ...  ...           ...           ...           ...
# 2214           NaN  ...             2             2             2
# 2215           NaN  ...           NaN           NaN           NaN
# 2216           NaN  ...      0.534653          0.55          0.61
# 2217           NaN  ...          0.19      0.292929      0.405941
# 2218           NaN  ...          0.86          1.09          1.05
#
#           yellow54      yellow46      yellow34      yellow35      yellow36  \
# 0     Myteacherssu  I’mlearninga  Thereisatlea  Myteacherstr  Whenmyteache
# 1             2018          2018          2018          2018          2018
# 2           yellow        yellow        yellow        yellow        yellow
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 2214             2           NaN           NaN           NaN           NaN
# 2215           NaN           NaN           NaN           NaN           NaN
# 2216           0.2          1.05          1.38          1.09      0.722772
# 2217           0.1          0.41          1.08           0.9          0.52
# 2218      0.646465          1.29          1.35           1.4       1.11111
#
#           yellow47      yellow53
# 0     Disciplineis  Adultsatthis
# 1             2018          2018
# 2           yellow        yellow
# 3              NaN           NaN
# 4              NaN           NaN
# ...            ...           ...
# 2214           NaN           NaN
# 2215           NaN           NaN
# 2216      0.535354          1.34
# 2217     0.0606061      0.525253
# 2218          0.56           NaN
#
# [2219 rows x 442 columns]

# %%
result1 = result
sch_meanyr = ['sch_mean2009','sch_mean2010','sch_mean2011','sch_mean2012','sch_mean2013','sch_mean2014','sch_mean2015','sch_mean2016','sch_mean2017','sch_mean2018']
for i in range(0, len(sch_meanyr)):
    idx = len(sch_meanyr)-1-i
    result1[sch_meanyr[idx]]='NaN'
    result1 = pd.concat([result1[[sch_meanyr[idx]]], result1.drop(sch_meanyr[idx], axis=1)], axis=1)
    result1 = result1.reset_index(drop = True)

yr = [2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
for i in range(3,len(result1)):
    for j in range(0,len(sch_meanyr)):
        s = result1.iloc[1]        
        a = list(s.index.values[(s == yr[j])])
        formean = result1.iloc[i][a]
        result1.loc[i,sch_meanyr[j]] = formean.mean(skipna = True)
        

result1
# Out:
#      sch_mean2009 sch_mean2010 sch_mean2011 sch_mean2012 sch_mean2013  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 2214          NaN          NaN          NaN          NaN            2
# 2215          NaN          NaN          NaN          NaN          NaN
# 2216     0.925532     0.925532     0.925532     0.471844     0.769819
# 2217      0.44898      0.44898      0.44898     0.146912     0.204147
# 2218      1.25275      1.25275      1.25275     0.664813      0.91814
#
#      sch_mean2014 sch_mean2015 sch_mean2016 sch_mean2017 sch_mean2018  ...  \
# 0             NaN          NaN          NaN          NaN          NaN  ...
# 1             NaN          NaN          NaN          NaN          NaN  ...
# 2             NaN          NaN          NaN          NaN          NaN  ...
# 3             NaN          NaN          NaN          NaN          NaN  ...
# 4             NaN          NaN          NaN          NaN          NaN  ...
# ...           ...          ...          ...          ...          ...  ...
# 2214            2            2            2            2            2  ...
# 2215          NaN          NaN          NaN          NaN          NaN  ...
# 2216     0.769819     0.949112     0.813405     0.757069     0.743198  ...
# 2217     0.204147     0.536998     0.512068     0.453068     0.429343  ...
# 2218      0.91814      1.04127      1.00391     0.922739     0.896481  ...
#
#           yellow42      yellow43      yellow44      yellow54      yellow46  \
# 0     Myteachersno  Myteachersgi  Myteachersex  Myteacherssu  I’mlearninga
# 1             2018          2018          2018          2018          2018
# 2           yellow        yellow        yellow        yellow        yellow
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 2214             2             2             2             2           NaN
# 2215           NaN           NaN           NaN           NaN           NaN
# 2216      0.534653          0.55          0.61           0.2          1.05
# 2217          0.19      0.292929      0.405941           0.1          0.41
# 2218          0.86          1.09          1.05      0.646465          1.29
#
#           yellow34      yellow35      yellow36      yellow47      yellow53
# 0     Thereisatlea  Myteacherstr  Whenmyteache  Disciplineis  Adultsatthis
# 1             2018          2018          2018          2018          2018
# 2           yellow        yellow        yellow        yellow        yellow
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 2214           NaN           NaN           NaN           NaN           NaN
# 2215           NaN           NaN           NaN           NaN           NaN
# 2216          1.38          1.09      0.722772      0.535354          1.34
# 2217          1.08           0.9          0.52     0.0606061      0.525253
# 2218          1.35           1.4       1.11111          0.56           NaN
#
# [2219 rows x 452 columns]

# %%
result1 = pd.concat([result1[['sch_mean_allyrs']], result1.drop('sch_mean_allyrs', axis=1)], axis=1)
result1 = pd.concat([result1[['sch_type']], result1.drop('sch_type', axis=1)], axis=1)
result1 = pd.concat([result1[['school_name']], result1.drop('school_name', axis=1)], axis=1)
result1 = pd.concat([result1[['index']], result1.drop('index', axis=1)], axis=1)
result1
# Out:
#          index                                        school_name  \
# 0     question                                                NaN
# 1         year                                                NaN
# 2        color                                                NaN
# 3       01M015                          P.S. 015 Roberto Clemente
# 4       01M019                                P.S. 019 Asher Levy
# ...        ...                                                ...
# 2214    75X469   P469X - THE BRONX SCHOOL FOR CONTINUOUS LEARNERS
# 2215    84K876           ACHIEVEMENT FIRST VOYAGER CHARTER SCHOOL
# 2216    84K892                  BROOKLYN EMERGING LEADERS ACADEMY
# 2217    84Q373  NEW VISIONS CHARTER HIGH SCHOOL FOR THE HUMANI...
# 2218    84X585                         LEGACY COLLEGE PREPARATORY
#
#                sch_type sch_mean_allyrs sch_mean2009 sch_mean2010  \
# 0                   NaN             NaN          NaN          NaN
# 1                   NaN             NaN          NaN          NaN
# 2                   NaN             NaN          NaN          NaN
# 3     Elementary School             NaN          NaN          NaN
# 4     Elementary School             NaN          NaN          NaN
# ...                 ...             ...          ...          ...
# 2214                NaN               2          NaN          NaN
# 2215                NaN             NaN          NaN          NaN
# 2216                NaN        0.743198     0.925532     0.925532
# 2217                NaN        0.429343      0.44898      0.44898
# 2218                NaN        0.896481      1.25275      1.25275
#
#      sch_mean2011 sch_mean2012 sch_mean2013 sch_mean2014  ...      yellow42  \
# 0             NaN          NaN          NaN          NaN  ...  Myteachersno
# 1             NaN          NaN          NaN          NaN  ...          2018
# 2             NaN          NaN          NaN          NaN  ...        yellow
# 3             NaN          NaN          NaN          NaN  ...           NaN
# 4             NaN          NaN          NaN          NaN  ...           NaN
# ...           ...          ...          ...          ...  ...           ...
# 2214          NaN          NaN            2            2  ...             2
# 2215          NaN          NaN          NaN          NaN  ...           NaN
# 2216     0.925532     0.471844     0.769819     0.769819  ...      0.534653
# 2217      0.44898     0.146912     0.204147     0.204147  ...          0.19
# 2218      1.25275     0.664813      0.91814      0.91814  ...          0.86
#
#           yellow43      yellow44      yellow54      yellow46      yellow34  \
# 0     Myteachersgi  Myteachersex  Myteacherssu  I’mlearninga  Thereisatlea
# 1             2018          2018          2018          2018          2018
# 2           yellow        yellow        yellow        yellow        yellow
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 2214             2             2             2           NaN           NaN
# 2215           NaN           NaN           NaN           NaN           NaN
# 2216          0.55          0.61           0.2          1.05          1.38
# 2217      0.292929      0.405941           0.1          0.41          1.08
# 2218          1.09          1.05      0.646465          1.29          1.35
#
#           yellow35      yellow36      yellow47      yellow53
# 0     Myteacherstr  Whenmyteache  Disciplineis  Adultsatthis
# 1             2018          2018          2018          2018
# 2           yellow        yellow        yellow        yellow
# 3              NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 2214           NaN           NaN           NaN           NaN
# 2215           NaN           NaN           NaN           NaN
# 2216          1.09      0.722772      0.535354          1.34
# 2217           0.9          0.52     0.0606061      0.525253
# 2218           1.4       1.11111          0.56           NaN
#
# [2219 rows x 452 columns]

# %%
wb = load_workbook('finalscores.xlsx')
sheet1 = wb.create_sheet('Sheet1',0)
active = wb['Sheet1']
# Write dataframe to active worksheet
for x in dataframe_to_rows(result1):
    active.append(x)
    
# Save workbook to write
wb.save('finalscores.xlsx')
